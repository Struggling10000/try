# %% [markdown]
# # 因子变量绘图
# 1.箱线图boxplot

# %%
# 竖着放的箱线图，也就是将x换成y
ax = sns.boxplot(y=tips["total_bill"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-90b2bd7dd64c> in <module>()
#       1 # 竖着放的箱线图，也就是将x换成y
# ----> 2 ax = sns.boxplot(y=tips["total_bill"])
#
# NameError: name 'sns' is not defined

# %%
# 分组绘制箱线图，分组因子是day，在x轴不同位置绘制
ax = sns.boxplot(x="day", y="total_bill", data=tips)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4c1527142410> in <module>()
#       1 # 分组绘制箱线图，分组因子是day，在x轴不同位置绘制
# ----> 2 ax = sns.boxplot(x="day", y="total_bill", data=tips)
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # 你好

# %%
# 在seaborn中用hue参数控制分组绘图。
# 分组箱线图，分子因子是smoker，不同的因子用不同颜色区分
# 相当于分组之后又分组
ax = sns.boxplot(x="day", y="total_bill", hue="smoker",
                    data=tips)

# %%
# 改变线宽，linewidth参数
ax = sns.boxplot(x="day", y="total_bill", hue="smoker",
                    data=tips, linewidth=2.5)

# %%
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")
tips = sns.load_dataset("tips")
# 绘制箱线图
sns.boxplot(x=tips["total_bill"])

# %%
# 改变x轴顺序，order参数
ax = sns.boxplot(x="day", y="total_bill", data=tips,
                    order=["Fri", "Thur", "Sat", "Sun"])

# %%
# 对dataframe的每个变量都绘制一个箱线图，水平放置
iris = sns.load_dataset("iris")
ax = sns.boxplot(data=iris, orient="h")

# %%
# 箱线图+有分布趋势的散点图
# 图形组合也就是两条绘图语句一起运行就可以了，相当于图形覆盖了
ax = sns.boxplot(x="day", y="total_bill", data=tips)
ax = sns.swarmplot(x="day", y="total_bill", data=tips, color=".1")

# %% [markdown]
# ## 2.小提琴图violinplot

# %%
import seaborn as sns
sns.set_style("whitegrid")
tips = sns.load_dataset("tips")
# 绘制小提琴图
ax = sns.violinplot(x=tips["total_bill"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f8a87349dd53> in <module>()
# ----> 1 import seaborn as sns
#       2 sns.set_style("whitegrid")
#       3 tips = sns.load_dataset("tips")
#       4 # 绘制小提琴图
#       5 ax = sns.violinplot(x=tips["total_bill"])
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# 分组的小提琴图，同上面的箱线图一样通过X轴分组
ax = sns.violinplot(x="day", y="total_bill", data=tips)

# %%
# 通过hue分组的小提琴图，相当于分组之后又分组
ax = sns.violinplot(x="day", y="total_bill", hue="smoker",
                        data=tips)

# %%
# 分组组合的小提琴图，其实就是hue分组后，各取一半组成一个小提琴图
ax = sns.violinplot(x="day", y="total_bill", hue="smoker",
                        data=tips,  split=True)

# %% [markdown]
# ## 3.散点图striplot

# %%
# 普通的散点图
ax1 = sns.stripplot(x=tips["total_bill"])

# %% [markdown]
# ## 4.带分布的散点图swarmplot

# %%
# 带分布密度的散点图
ax2 = sns.swarmplot(x=tips["total_bill"])

# %%
# 分组的散点图
ax = sns.stripplot(x="day", y="total_bill", data=tips)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5df948eb1b79> in <module>()
#       1 # 分组的散点图
# ----> 2 ax = sns.stripplot(x="day", y="total_bill", data=tips)
#
# NameError: name 'sns' is not defined

# %%
# 添加抖动项的散点图，jitter可以是0.1,0.2...这样的小数，表示抖动的程度大小
ax = sns.stripplot(x="day", y="total_bill", data=tips, jitter=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ff0734f72fee> in <module>()
#       1 # 添加抖动项的散点图，jitter可以是0.1,0.2...这样的小数，表示抖动的程度大小
# ----> 2 ax = sns.stripplot(x="day", y="total_bill", data=tips, jitter=True)
#
# NameError: name 'sns' is not defined

# %%
# 是不是想横着放呢，很简单的，x-y顺序换一下就好了
ax = sns.stripplot(x="total_bill", y="day", data=tips,jitter=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-18b957fba2cc> in <module>()
#       1 # 是不是想横着放呢，很简单的，x-y顺序换一下就好了
# ----> 2 ax = sns.stripplot(x="total_bill", y="day", data=tips,jitter=True)
#
# NameError: name 'sns' is not defined

# %%
# 散点图+小提起图
# 两条命令一起运行就行了
ax = sns.violinplot(x="day", y="total_bill", data=tips,inner=None, color=".8")
ax = sns.stripplot(x="day", y="total_bill", data=tips,jitter=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2a9d8ab344ff> in <module>()
#       1 # 散点图+小提起图
#       2 # 两条命令一起运行就行了
# ----> 3 ax = sns.violinplot(x="day", y="total_bill", data=tips,inner=None, color=".8")
#       4 ax = sns.stripplot(x="day", y="total_bill", data=tips,jitter=True)
#
# NameError: name 'sns' is not defined

# %%
# 箱线图+散点图
# whis 参数设定是否显示箱线图的离群点，whis=np.inf 表示不显示
import numpy as np
ax = sns.boxplot(x="tip", y="day", data=tips, whis=np.inf)
ax = sns.swarmplot(x="tip", y="day", data=tips)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-936494fea3e6> in <module>()
#       2 # whis 参数设定是否显示箱线图的离群点，whis=np.inf 表示不显示
#       3 import numpy as np
# ----> 4 ax = sns.boxplot(x="tip", y="day", data=tips, whis=np.inf)
#       5 ax = sns.swarmplot(x="tip", y="day", data=tips)
#
# NameError: name 'sns' is not defined

# %% [markdown]
# ## 5.直方图barplot

# %% [markdown]
# 直方图的统计函数，绘制的是变量的均值 estimator=np.mean
# 我不喜欢显示直方图上面的置信度线，难看，所以下面的图形我都设置ci=0.(Size of confidence intervals to draw around estimated values)

# %%
# 注意看看Y轴，看到没，统计函数默认是 mean，
import seaborn as sns
sns.set_style("whitegrid")
tips = sns.load_dataset("tips")
ax = sns.barplot(x="day", y="total_bill", data=tips,ci=0)

# %%
# 分组的柱状图
ax = sns.barplot(x="day", y="total_bill", hue="sex", data=tips,ci=0)

# %%
# 绘制变量中位数的直方图，estimator指定统计函数
from numpy import median
ax = sns.barplot(x="day", y="tip", data=tips, 
                    estimator=median, ci=0)

# %%
# 改变主题颜色
# palette="Blues_d"
ax = sns.barplot("size", y="total_bill", data=tips, 
                    palette="Blues_d")

# %% [markdown]
# ## 6.计数的直方图countplot

# %%
import seaborn as sns
sns.set(style="darkgrid")
titanic = sns.load_dataset("titanic")
ax = sns.countplot(x="class", data=titanic)

# %%
# 分组绘图
ax = sns.countplot(x="class", hue="who", data=titanic)

# %%
# 如果是横着放，x用y替代
ax = sns.countplot(y="class", hue="who", data=titanic)

# %% [markdown]
# ## 回归图

# %% [markdown]
# ## 1.线性回归图lmplot

# %%
# 线性回归图
import seaborn as sns; sns.set(color_codes=True)
tips = sns.load_dataset("tips")
g = sns.lmplot(x="total_bill", y="tip", data=tips)

# %% [markdown]
# ## 2.线性回归图regplot

# %%
import seaborn as sns; sns.set(color_codes=True)
tips = sns.load_dataset("tips")
ax = sns.regplot(x="total_bill", y="tip", data=tips)

# %% [markdown]
# # 热力图

# %% [markdown]
# ## 1.热力图heatmap

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set()
uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(uniform_data)

# %%
# 改变颜色映射的值范围
ax = sns.heatmap(uniform_data, vmin=0, vmax=1)

# %%
#Plot a dataframe with meaningful row and column labels:
# 绘制x-y-z的热力图，比如 年-月-销量 的热力图
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
ax = sns.heatmap(flights)
